# %% [markdown]
# <a href="https://colab.research.google.com/github/Atin2001/Python/blob/main/Python_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#statisticsをインポート
import statistics

# %%
#平均値を出す場合
a = [1,2,3,4,5,5,6]
statistics.mean(a)
# Out:
# 3.7142857142857144

# %%
#sumとlenはそのまま使うことができるが、meanを直接出すことはできない

# %%
sum(a)/len(a)
# Out:
# 3.7142857142857144

# %%
mean(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_160/3531512137.py in <cell line: 0>()
# ----> 1 mean(a)
#
# NameError: name 'mean' is not defined

# %%
#中央値
statistics.median(a)
# Out:
# 4

# %%
#最頻値
statistics.mode(a)
# Out:
# 5

# %%
#分散
statistics.variance(a)
# Out:
# 3.238095238095238

# %%
#標準偏差
statistics.stdev(a)
# Out:
# 1.7994708216848747
