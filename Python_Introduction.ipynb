# %% [markdown]
# <a href="https://colab.research.google.com/github/Atin2001/Python/blob/main/Python_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
2*2
# Out:
# 4

# %%
5 // 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 % 2
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
2 ^ 3
# Out:
# 1

# %%
a = 10
b = 5

# %%
a
# Out:
# 10

# %%
b
# Out:
# 5

# %%
a > b
# Out:
# True

# %%
b > a
# Out:
# False

# %%
a == b
# Out:
# False
