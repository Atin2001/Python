# %% [markdown]
# <a href="https://colab.research.google.com/github/Atin2001/Python/blob/main/Python_VariableStyle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#int型(整数値)

# %%
type(1)
# Out:
# int

# %%
#float型(浮動小数点)

# %%
type(1.2)
# Out:
# float

# %%
#str型(文字列)

# %%
type("Hello")
# Out:
# str

# %%
#datetime型(日付データ)

# %%
import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2026-03-05 01:43:08.349455

# %%
type(now)
# Out:
# datetime.datetime

# %%
#bool型(真偽)

# %%
type(True)
# Out:
# bool

# %%
1 == 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
## list型(だいかっこの中に、カンマで数値や文字列を並べたもの)

# %%
a = {1,2,""Hello}
type(a)
# Out:
#   File "/tmp/ipykernel_462/3365162260.py", line 1
#     a = {1,2,""Hello}
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
a = {1,2,"Hello"}
type(a)
# Out:
# set

# %%
a = [1,2,"Hello"]
type(a)
# Out:
# list

# %%
# tuple型(通常のかっこ。中身の変更ができる。list型ではできない)

# %%
a = (1,2,"Hello")
type(a)
# Out:
# tuple

# %%
#dict型（辞書型。要素を取り出すのに便利）

# %%
a = {
    "Key1" : "Hello",
    "Key2" : "Bye" ,
    "num" : 1
}
a
# Out:
# {'Key1': 'Hello', 'Key2': 'Bye', 'num': 1}

# %%
a = {
    "Key1" : "Hello",
    "Key2" : "Bye" ,
    "num" : 1
}
type(a)
# Out:
# dict

# %%
a["Key1"]
# Out:
# 'Hello'

# %%
#文字列str型を、整数値int型に変える時

# %%
type(int("10"))
# Out:
# int

# %%
##これではできない
10 + "10"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_462/4177318172.py in <cell line: 0>()
#       1 ##これではできない
# ----> 2 10 + "10"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
##これならできる
10 + int("10")
# Out:
# 20

# %%
#int→strに変換
str(10)
# Out:
# '10'

# %%
"10" + str(10)
# Out:
# '1010'
