# %% [markdown]
# <a href="https://colab.research.google.com/github/Atin2001/Python/blob/main/Python_random%E3%83%A2%E3%82%B8%E3%83%A5%E3%83%BC%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#サンプリング
#データサイエンスでは、このランダムモジュールを使う！

import random

a = [1,2,3,4,5]
random.choice(a)
# Out:
# 2

# %%
#複数個の要素を取り出したいときは？
#重複は考慮しない
random.sample(a,2)
# Out:
# [1, 5]

# %%
#重複も認める場合
random.choices(a, k=10)
# Out:
# [3, 4, 4, 1, 2, 1, 5, 2, 3, 2]

# %%
#乱数を発生させた場合、固定するとき
random.seed(42)

random.choices(a, k=10)
# Out:
# [4, 1, 2, 2, 4, 4, 5, 1, 3, 1]

# %% [markdown]
# ## 乱数発生

# %%
random.random()
#0から1の間の小数が返ってくる
# Out:
# 0.21863797480360336

# %%
#範囲を指定する場合
random.uniform(0,100)
# Out:
# 2.6535969683863625

# %%
#整数値で返す場合
random.seed(42)
random.randint(0,100)
# Out:
# 81
